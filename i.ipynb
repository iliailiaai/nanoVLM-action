# %%
# %cd nanoVLM 
# %pip install torch numpy torchvision pillow datasets huggingface-hub transformers wandb einops

# %%
# !git check-ignore -v nanoVLM-action/nanoVLM/data/emptyenv_sft_dataset/
# Out:
# .gitignore:2:nanoVLM-action/nanoVLM/data/emptyenv_sft_dataset/	nanoVLM-action/nanoVLM/data/emptyenv_sft_dataset/

# %%
# !git rm -r --cached nanoVLM-action/nanoVLM/data/emptyenv_sft_dataset/
# Out:
# fatal: pathspec 'nanoVLM-action/nanoVLM/data/emptyenv_sft_dataset/' did not match any files

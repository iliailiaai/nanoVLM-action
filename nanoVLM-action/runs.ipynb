# %%
# %cd nanoVLM
# Out:
# /teamspace/studios/this_studio/nanoVLM
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python train_action_sft.py \
  --jsonl /teamspace/studios/this_studio/nanoVLM/data/emptyenv_sft_dataset/dataset.jsonl \
  --images_root /teamspace/studios/this_studio/nanoVLM/data/emptyenv_sft_dataset \
  --batch_size 16 \
  --max_steps 5000 \
  --val_ratio 0.10 \
  --lr_mp 0.005 \
  --lr_head 0.005 \
  --max_length 2048 \
  --log_every 4 \
  --eval_every 250 \
  --out checkpoints_emptyenv_action
# Out:
# Resize to max side len: True
# Loading from backbone weights
# Successfully loaded google/siglip2-base-patch16-512 weights from safetensors. Model has 86,433,024 parameters.
# Extending token embeddings from torch.Size([49152, 960]) to torch.Size([49218, 960])
# Initialized 66 new token embeddings
# Successfully loaded HuggingFaceTB/SmolLM2-360M-Instruct weights from safetensors. Model has 361,884,480 parameters.
# compiling model...
# Dataset length: 20000
# Fetching sample 0 ...
# Fetched sample 0 in 0.01584172248840332 sec
# input_ids: torch.Size([107]) label: 0
# num image chunks: 1
# eval...
# 100%|█████████████████████████████████████████| 125/125 [00:35<00:00,  3.52it/s]
# val_loss 0.8775 | val_acc 0.683
# ...
# 100%|█████████████████████████████████████████| 125/125 [00:25<00:00,  4.87it/s]
# [VAL] step    250 | val_loss 0.0712 | val_acc 0.984
# Saved checkpoint to: checkpoints_emptyenv_action/step_250
# ...

# %%
# base 5000 

# !python train_action_sft.py \
  --jsonl /teamspace/studios/this_studio/nanoVLM/data/emptyenv_sft_dataset/dataset.jsonl \
  --images_root /teamspace/studios/this_studio/nanoVLM/data/emptyenv_sft_dataset \
  --batch_size 16 \
  --max_steps 5000 \
  --val_ratio 0.10 \
  --lr_mp 0.005 \
  --lr_head 0.005 \
  --max_length 2048 \
  --log_every 1 \
  --eval_every 125 \
  --out checkpoints_emptyenv_action
# Out:
# /teamspace/studios/this_studio/nanoVLM
# ...
# Resize to max side len: True
# Loading from backbone weights
# Successfully loaded google/siglip2-base-patch16-512 weights from safetensors. Model has 86,433,024 parameters.
# Extending token embeddings from torch.Size([49152, 960]) to torch.Size([49218, 960])
# Initialized 66 new token embeddings
# Successfully loaded HuggingFaceTB/SmolLM2-360M-Instruct weights from safetensors. Model has 361,884,480 parameters.
# compiling model...
# Dataset length: 5000
# Fetching sample 0 ...
# Fetched sample 0 in 0.01434946060180664 sec
# input_ids: torch.Size([107]) label: 0
# num image chunks: 1
# eval...
# ...
